# %%
import pandas as pd

# Load the merged features data
merged_features = pd.read_csv('../clean_data/merged_features.csv')

# Display basic info
print("Shape:", merged_features.shape)
print("\nFirst few rows:")
print(merged_features.head())

print("\nData types:")
print(merged_features.dtypes)

print("\nMissing values:")
print(merged_features.isnull().sum())

print("\nBasic statistics:")
print(merged_features.describe())
# Out:
# Shape: (35040, 47)
#
# First few rows:
#   interval_start_local          load             datetime  temp   TEMP_qc  \
# 0  2021-01-01 00:00:00  43530.833333  2021-01-01 00:00:00  3.30  3.000000
# 1  2021-01-01 01:00:00  43192.500000  2021-01-01 01:00:00  3.20  5.000000
# 2  2021-01-01 02:00:00  43059.916667  2021-01-01 02:00:00  3.30  5.000000
# 3  2021-01-01 03:00:00  43245.666667  2021-01-01 03:00:00  3.25  4.333333
# 4  2021-01-01 04:00:00  43783.500000  2021-01-01 04:00:00  2.90  5.000000
#
#       DEW_C    DEW_qc  SLP_hPa    SLP_qc  WIND_DIR_deg  ...  SLP_qc_ramp_3h  \
# 0  2.800000  3.000000  1002.30  3.000000     25.000000  ...             NaN
# 1  2.866667  5.000000  1003.20  7.666667    243.333333  ...             NaN
# 2  3.175000  5.000000  1003.00  8.000000    312.500000  ...             NaN
# 3  2.916667  4.333333  1003.15  7.000000    316.666667  ...        4.000000
# 4  2.900000  5.000000  1002.50  7.000000    325.000000  ...        0.666667
#
#    WIND_DIR_deg_ramp_1h  WIND_DIR_deg_ramp_3h  WIND_DIR_qc_ramp_1h  \
# 0                   NaN                   NaN                  NaN
# 1            218.333333                   NaN             2.000000
# 2             69.166667                   NaN             0.000000
# 3              4.166667            291.666667             0.666667
# 4              8.333333             81.666667             0.666667
#
#    WIND_DIR_qc_ramp_3h  WIND_SPD_ms_ramp_1h WIND_SPD_ms_ramp_3h  \
# 0                  NaN                  NaN                 NaN
# 1                  NaN             4.133333                 NaN
# 2                  NaN             0.566667                 NaN
# 3             1.333333             0.333333            4.366667
# 4             0.000000             0.166667            0.066667
#
#    WIND_SPD_qc_ramp_1h  WIND_SPD_qc_ramp_3h  has_full_lags
# 0                  NaN                  NaN          False
# 1             2.000000                  NaN          False
# 2             0.000000                  NaN          False
# 3             0.666667             1.333333          False
# 4             0.666667             0.000000          False
#
# [5 rows x 47 columns]
#
# Data types:
# interval_start_local     object
# load                    float64
# datetime                 object
# temp                    float64
# TEMP_qc                 float64
# DEW_C                   float64
# DEW_qc                  float64
# SLP_hPa                 float64
# SLP_qc                  float64
# WIND_DIR_deg            float64
# WIND_DIR_qc             float64
# WIND_SPD_ms             float64
# WIND_SPD_qc             float64
# hour                      int64
# dayofweek                 int64
# is_weekend                 bool
# season                   object
# is_holiday                 bool
# load_lag_1h             float64
# load_lag_24h            float64
# load_lag_168h           float64
# temp_sq                 float64
# temp_x_hour             float64
# cooling_degree_hours    float64
# heating_degree_hours    float64
# temp_ramp_1h            float64
# temp_ramp_3h            float64
# temp_rollstd_6h         float64
# TEMP_qc_ramp_1h         float64
# TEMP_qc_ramp_3h         float64
# DEW_C_ramp_1h           float64
# DEW_C_ramp_3h           float64
# DEW_qc_ramp_1h          float64
# DEW_qc_ramp_3h          float64
# SLP_hPa_ramp_1h         float64
# SLP_hPa_ramp_3h         float64
# SLP_qc_ramp_1h          float64
# SLP_qc_ramp_3h          float64
# WIND_DIR_deg_ramp_1h    float64
# WIND_DIR_deg_ramp_3h    float64
# WIND_DIR_qc_ramp_1h     float64
# WIND_DIR_qc_ramp_3h     float64
# WIND_SPD_ms_ramp_1h     float64
# WIND_SPD_ms_ramp_3h     float64
# WIND_SPD_qc_ramp_1h     float64
# WIND_SPD_qc_ramp_3h     float64
# has_full_lags              bool
# dtype: object
#
# Missing values:
# interval_start_local       0
# load                       7
# datetime                   0
# temp                       7
# TEMP_qc                   14
# DEW_C                     10
# DEW_qc                    14
# SLP_hPa                   43
# SLP_qc                     5
# WIND_DIR_deg            1892
# WIND_DIR_qc                5
# WIND_SPD_ms               10
# WIND_SPD_qc                8
# hour                       0
# dayofweek                  0
# is_weekend                 0
# season                     0
# is_holiday                 0
# load_lag_1h                8
# load_lag_24h              31
# load_lag_168h            175
# temp_sq                    7
# temp_x_hour                7
# cooling_degree_hours       7
# heating_degree_hours       7
# temp_ramp_1h              12
# temp_ramp_3h              15
# temp_rollstd_6h            2
# TEMP_qc_ramp_1h           25
# TEMP_qc_ramp_3h           29
# DEW_C_ramp_1h             17
# DEW_C_ramp_3h             21
# DEW_qc_ramp_1h            25
# DEW_qc_ramp_3h            29
# SLP_hPa_ramp_1h           74
# SLP_hPa_ramp_3h           85
# SLP_qc_ramp_1h             8
# SLP_qc_ramp_3h            11
# WIND_DIR_deg_ramp_1h    3077
# WIND_DIR_deg_ramp_3h    3335
# WIND_DIR_qc_ramp_1h        8
# WIND_DIR_qc_ramp_3h       11
# WIND_SPD_ms_ramp_1h       18
# WIND_SPD_ms_ramp_3h       21
# WIND_SPD_qc_ramp_1h       14
# WIND_SPD_qc_ramp_3h       17
# has_full_lags              0
# dtype: int64
#
# Basic statistics:
#                load          temp       TEMP_qc         DEW_C        DEW_qc  \
# count  35033.000000  35033.000000  35026.000000  35030.000000  35026.000000
# mean   49466.249680     20.362597      4.439235     11.375811      4.439705
# std    10980.867091      9.780091      1.074529      9.293148      1.075036
# min    27795.750000    -17.750000      1.000000    -21.100000      1.000000
# 25%    41550.000000     13.300000      3.000000      4.200000      3.000000
# 50%    46772.250000     21.700000      5.000000     13.900000      5.000000
# 75%    55310.000000     27.800000      5.000000     19.400000      5.000000
# max    85517.750000     42.800000      9.000000     27.000000      9.000000
#
#             SLP_hPa        SLP_qc  WIND_DIR_deg   WIND_DIR_qc   WIND_SPD_ms  \
# count  34997.000000  35035.000000  33148.000000  35035.000000  35030.000000
# mean    1015.172593      4.672833    175.026065      4.764027      4.635777
# std        6.531405      1.319578     87.886888      1.468686      2.489205
# min      991.100000      1.000000     10.000000      1.000000      0.000000
# 25%     1010.950000      3.000000    130.000000      3.000000      2.850000
# 50%     1014.400000      5.000000    170.000000      5.000000      4.350000
# 75%     1018.800000      5.000000    200.000000      5.000000      6.200000
# max     1042.800000      9.000000    360.000000      9.000000     18.662500
#
#        ...  SLP_qc_ramp_1h  SLP_qc_ramp_3h  WIND_DIR_deg_ramp_1h  \
# count  ...    35032.000000    35029.000000          31963.000000
# mean   ...        1.546794        0.497808             25.234276
# std    ...        1.164322        0.949961             55.924614
# min    ...        0.000000        0.000000              0.000000
# 25%    ...        0.000000        0.000000              5.000000
# 50%    ...        2.000000        0.000000             10.000000
# 75%    ...        2.000000        0.000000             20.000000
# max    ...        6.666667        6.666667            350.000000
#
#        WIND_DIR_deg_ramp_3h  WIND_DIR_qc_ramp_1h  WIND_DIR_qc_ramp_3h  \
# count          31705.000000         35032.000000         35029.000000
# mean              41.411617             1.508136             0.659469
# std               71.031486             1.248154             1.331023
# min                0.000000             0.000000             0.000000
# 25%               10.000000             0.000000             0.000000
# 50%               20.000000             2.000000             0.000000
# 75%               36.666667             2.000000             0.666667
# max              350.000000             8.000000             8.000000
#
#        WIND_SPD_ms_ramp_1h  WIND_SPD_ms_ramp_3h  WIND_SPD_qc_ramp_1h  \
# count         35022.000000         35019.000000         35026.000000
# mean              0.915427             1.433298             1.399364
# std               0.891976             1.247676             1.046154
# min               0.000000             0.000000             0.000000
# 25%               0.250000             0.500000             0.000000
# 50%               0.666667             1.100000             2.000000
# 75%               1.300000             2.100000             2.000000
# max              11.600000            16.562500             8.000000
#
#        WIND_SPD_qc_ramp_3h
# count         35023.000000
# mean              0.225745
# std               0.614390
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               8.000000
#
# [8 rows x 41 columns]

# %%
# name all columns
print("\nColumn names:")
for col in merged_features.columns:
    print(col)
# Out:
# Column names:
# interval_start_local
# load
# datetime
# temp
# TEMP_qc
# DEW_C
# DEW_qc
# SLP_hPa
# SLP_qc
# WIND_DIR_deg
# WIND_DIR_qc
# WIND_SPD_ms
# WIND_SPD_qc
# hour
# dayofweek
# is_weekend
# season
# is_holiday
# load_lag_1h
# load_lag_24h
# load_lag_168h
# temp_sq
# temp_x_hour
# cooling_degree_hours
# heating_degree_hours
# temp_ramp_1h
# temp_ramp_3h
# temp_rollstd_6h
# TEMP_qc_ramp_1h
# TEMP_qc_ramp_3h
# DEW_C_ramp_1h
# DEW_C_ramp_3h
# DEW_qc_ramp_1h
# DEW_qc_ramp_3h
# SLP_hPa_ramp_1h
# SLP_hPa_ramp_3h
# SLP_qc_ramp_1h
# SLP_qc_ramp_3h
# WIND_DIR_deg_ramp_1h
# WIND_DIR_deg_ramp_3h
# WIND_DIR_qc_ramp_1h
# WIND_DIR_qc_ramp_3h
# WIND_SPD_ms_ramp_1h
# WIND_SPD_ms_ramp_3h
# WIND_SPD_qc_ramp_1h
# WIND_SPD_qc_ramp_3h
# has_full_lags

# %%
# look at is_holiday column
merged_features['is_holiday'].value_counts()
# Out:
# is_holiday
# False    33984
# True      1056
# Name: count, dtype: int64

# %%
# Look at temperature statistics
print("\nTemperature statistics:")
print(merged_features['temp'].describe())
# Out:
# Temperature statistics:
# count    35033.000000
# mean        20.362597
# std          9.780091
# min        -17.750000
# 25%         13.300000
# 50%         21.700000
# 75%         27.800000
# max         42.800000
# Name: temp, dtype: float64

# %%
# Look at where temp is less than -10 or greater than 120
extreme_temps = merged_features[(merged_features['temp'] < -10) | (merged_features['temp'] > 120)]
print("\nExtreme temperature records:")
print(extreme_temps)
# Out:
# Extreme temperature records:
#       interval_start_local          load             datetime   temp  TEMP_qc  \
# 1078   2021-02-14 22:00:00  66296.916667  2021-02-14 22:00:00 -10.60      5.0
# 1079   2021-02-14 23:00:00  65548.833333  2021-02-14 23:00:00 -10.85      5.0
# 1080   2021-02-15 00:00:00  64477.666667  2021-02-15 00:00:00 -11.55      5.0
# 1081   2021-02-15 01:00:00  59322.916667  2021-02-15 01:00:00 -11.70      5.0
# 1082   2021-02-15 02:00:00  54252.500000  2021-02-15 02:00:00 -11.70      5.0
# ...                    ...           ...                  ...    ...      ...
# 26631  2024-01-15 15:00:00  70917.583333  2024-01-15 15:00:00 -11.46      4.2
# 26632  2024-01-15 16:00:00  71249.583333  2024-01-15 16:00:00 -10.30      5.0
# 26651  2024-01-16 11:00:00  72148.333333  2024-01-16 11:00:00 -10.60      5.0
# 26652  2024-01-16 12:00:00  70151.666667  2024-01-16 12:00:00 -10.85      3.0
# 26653  2024-01-16 13:00:00  67693.833333  2024-01-16 13:00:00 -11.10      5.0
#
#        DEW_C  DEW_qc  SLP_hPa    SLP_qc  WIND_DIR_deg  ...  SLP_qc_ramp_3h  \
# 1078  -12.80     5.0  1025.50  5.000000         350.0  ...        2.000000
# 1079  -13.05     5.0  1026.20  7.000000         345.0  ...        0.666667
# 1080  -13.75     5.0  1026.60  6.600000         342.5  ...        0.600000
# 1081  -13.70     5.0  1027.70  7.666667         340.0  ...        2.666667
# 1082  -14.40     5.0  1027.50  8.000000         345.0  ...        1.000000
# ...      ...     ...      ...       ...           ...  ...             ...
# 26631 -14.10     4.2  1027.00  6.600000         150.0  ...        1.600000
# 26632 -14.45     5.0  1027.40  7.000000         185.0  ...        0.000000
# 26651 -17.80     5.0  1032.80  5.000000         340.0  ...        0.000000
# 26652 -17.80     3.0  1033.25  3.000000         340.0  ...        0.000000
# 26653 -18.90     5.0  1033.60  5.000000         340.0  ...        0.000000
#
#        WIND_DIR_deg_ramp_1h  WIND_DIR_deg_ramp_3h  WIND_DIR_qc_ramp_1h  \
# 1078               2.500000            340.000000                  2.0
# 1079               5.000000             11.666667                  0.0
# 1080               2.500000             10.000000                  0.0
# 1081               2.500000             10.000000                  0.0
# 1082               5.000000              0.000000                  0.0
# ...                     ...                   ...                  ...
# 26631            203.333333            200.000000                  0.8
# 26632             35.000000            170.000000                  0.8
# 26651             10.000000              0.000000                  0.0
# 26652              0.000000              5.000000                  2.0
# 26653              0.000000             10.000000                  2.0
#
#        WIND_DIR_qc_ramp_3h  WIND_SPD_ms_ramp_1h WIND_SPD_ms_ramp_3h  \
# 1078              0.000000                0.350            0.250000
# 1079              0.000000                0.300            0.100000
# 1080              2.000000                0.375            0.275000
# 1081              0.000000                0.925            1.000000
# 1082              0.000000                0.400            0.900000
# ...                    ...                  ...                 ...
# 26631             0.533333                0.480            1.013333
# 26632             0.000000                0.970            0.500000
# 26651             0.000000                0.500            1.600000
# 26652             0.000000                0.250            1.050000
# 26653             0.000000                1.350            1.600000
#
#        WIND_SPD_qc_ramp_1h  WIND_SPD_qc_ramp_3h  has_full_lags
# 1078                   2.0             0.000000           True
# 1079                   0.0             0.000000           True
# 1080                   0.0             2.000000           True
# 1081                   0.0             0.000000           True
# 1082                   0.0             0.000000           True
# ...                    ...                  ...            ...
# 26631                  0.8             0.533333           True
# 26632                  0.8             0.000000           True
# 26651                  0.0             0.000000           True
# 26652                  2.0             0.000000           True
# 26653                  2.0             0.000000           True
#
# [76 rows x 47 columns]

# %%
# Look for load outliers
load_outliers = merged_features[(merged_features['load'] < 0) | (merged_features['load'] > 85000)]
print("\nLoad outliers:")
print(load_outliers)
# Out:
# Load outliers:
#       interval_start_local          load             datetime  temp  TEMP_qc  \
# 22840  2023-08-10 16:00:00  85186.000000  2023-08-10 16:00:00  35.6      5.0
# 22841  2023-08-10 17:00:00  85424.333333  2023-08-10 17:00:00  36.7      5.0
# 23080  2023-08-20 16:00:00  85110.500000  2023-08-20 16:00:00  40.0      5.0
# 31841  2024-08-19 17:00:00  85276.583333  2024-08-19 17:00:00  38.3      5.0
# 31864  2024-08-20 16:00:00  85431.583333  2024-08-20 16:00:00  33.9      5.0
# 31865  2024-08-20 17:00:00  85517.750000  2024-08-20 17:00:00  35.0      5.0
# 31888  2024-08-21 16:00:00  85059.583333  2024-08-21 16:00:00  30.6      5.0
#
#        DEW_C  DEW_qc  SLP_hPa  SLP_qc  WIND_DIR_deg  ...  SLP_qc_ramp_3h  \
# 22840   22.8     5.0   1008.8     5.0         220.0  ...             0.0
# 22841   22.2     5.0   1008.2     5.0           NaN  ...             0.0
# 23080   17.8     5.0   1016.2     5.0         360.0  ...             0.0
# 31841   20.0     5.0   1014.9     5.0           NaN  ...             0.0
# 31864   22.2     5.0   1015.5     5.0           NaN  ...             0.0
# 31865   22.8     5.0   1015.2     5.0           NaN  ...             0.0
# 31888   20.0     5.0   1016.2     5.0         140.0  ...             0.0
#
#        WIND_DIR_deg_ramp_1h  WIND_DIR_deg_ramp_3h  WIND_DIR_qc_ramp_1h  \
# 22840                   5.0                  10.0                  2.0
# 22841                   NaN                   NaN                  4.0
# 23080                  25.0                 350.0                  2.0
# 31841                   NaN                   NaN                  0.0
# 31864                   NaN                   NaN                  6.0
# 31865                   NaN                   NaN                  0.0
# 31888                   0.0                  10.0                  2.0
#
#        WIND_DIR_qc_ramp_3h  WIND_SPD_ms_ramp_1h WIND_SPD_ms_ramp_3h  \
# 22840                  0.0                 0.50                 0.5
# 22841                  4.0                 4.10                 4.6
# 23080                  0.0                 0.50                 1.0
# 31841                  4.0                 2.60                 3.6
# 31864                  4.0                 3.35                 3.1
# 31865                  4.0                 2.10                 1.5
# 31888                  0.0                 1.05                 0.5
#
#        WIND_SPD_qc_ramp_1h  WIND_SPD_qc_ramp_3h  has_full_lags
# 22840                  2.0                  0.0           True
# 22841                  0.0                  0.0           True
# 23080                  2.0                  0.0           True
# 31841                  0.0                  0.0           True
# 31864                  2.0                  0.0           True
# 31865                  0.0                  0.0           True
# 31888                  2.0                  0.0           True
#
# [7 rows x 47 columns]
