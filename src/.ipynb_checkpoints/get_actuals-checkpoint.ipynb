# %%
import os
from dotenv import load_dotenv
from gridstatus import Ercot, Markets
from gridstatusio import GridStatusClient
from datetime import datetime, timedelta

# Load .env
load_dotenv()

API_KEY = os.getenv("GRIDSTATUS_API_KEY")
if API_KEY is None:
    raise RuntimeError("GRIDSTATUS_API_KEY not found in environment variables.")

client = GridStatusClient(api_key=API_KEY)
grid = Ercot()
QUERY_LIMIT = 100

def get_load_actuals(client):
    """Get ERCOT load actuals for a specific date range."""
    df = client.get_dataset(
    dataset="ercot_load",
    start="2021-1-1",
    end="2024-12-31",
    timezone="market",
    )
 
    return df

def get_net_load_actuals(client):
    """Get ERCOT load actuals for a specific date range."""
    df = client.get_dataset(
    dataset="ercot_net_load",
    start="2021-1-1",
    end="2022-12-31",
    timezone="market",
    )
 
    return df


load_actuals_df = get_load_actuals(client)
print(load_actuals_df.head())
# Out:
# 2025-11-23 13:33:42 - INFO - Fetching Page 1...
# 2025-11-23 13:33:42 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:42 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:33:45 - INFO - Done in 2.78 seconds.
# 2025-11-23 13:33:45 - INFO - Fetching Page 2...
# 2025-11-23 13:33:45 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:45 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 2, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMS0wNi0yMyAyMDozNTowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA1MDAwMH0=', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:33:47 - INFO - Done in 2.54 seconds. Total time: 5.32s. Avg per page: 2.66s
# 2025-11-23 13:33:47 - INFO - Fetching Page 3...
# 2025-11-23 13:33:47 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:47 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 3, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMS0xMi0xNCAxMToxNTowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAxMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:33:50 - INFO - Done in 2.58 seconds. Total time: 7.9s. Avg per page: 2.63s
# 2025-11-23 13:33:50 - INFO - Fetching Page 4...
# 2025-11-23 13:33:50 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:50 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 4, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMi0wNi0wNiAwMTo1NTowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAxNTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:33:52 - INFO - Done in 2.57 seconds. Total time: 10.46s. Avg per page: 2.62s
# 2025-11-23 13:33:52 - INFO - Fetching Page 5...
# 2025-11-23 13:33:52 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:52 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 5, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMi0xMS0yNiAxNjozNTowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAyMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:33:55 - INFO - Done in 2.64 seconds. Total time: 13.1s. Avg per page: 2.62s
# 2025-11-23 13:33:55 - INFO - Fetching Page 6...
# 2025-11-23 13:33:55 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:55 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 6, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMy0wNS0xOSAwNzoxNTowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAyNTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:33:58 - INFO - Done in 2.87 seconds. Total time: 15.97s. Avg per page: 2.66s
# 2025-11-23 13:33:58 - INFO - Fetching Page 7...
# 2025-11-23 13:33:58 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:33:58 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 7, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyMy0xMS0wOSAwNjozMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAzMDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:34:00 - INFO - Done in 2.58 seconds. Total time: 18.55s. Avg per page: 2.65s
# 2025-11-23 13:34:00 - INFO - Fetching Page 8...
# 2025-11-23 13:34:00 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:34:00 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 8, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyNC0wNS0wMSAwMDo1NTowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiAzNTAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:34:03 - INFO - Done in 2.52 seconds. Total time: 21.07s. Avg per page: 2.63s
# 2025-11-23 13:34:03 - INFO - Fetching Page 9...
# 2025-11-23 13:34:03 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load/query
# 2025-11-23 13:34:03 - INFO - Params: {'start_time': Timestamp('2021-01-01 00:00:00'), 'end_time': Timestamp('2024-12-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 9, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': None, 'timezone': 'market', 'cursor': 'eyJjb2x1bW5zIjogWyJpbnRlcnZhbF9zdGFydF91dGMiXSwgInZhbHVlcyI6IFsiMjAyNC0xMC0yMSAxODozMDowMCswMDowMCJdLCAidG90YWxfcm93c19yZXR1cm5lZF9zb19mYXIiOiA0MDAwMDB9', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-23 13:34:04 - INFO - Done in 1.37 seconds. Total time: 22.44s. Avg per page: 2.49s
# 2025-11-23 13:34:04 - INFO - Total number of rows: 420283
#        interval_start_local        interval_start_utc  \
# 0 2021-01-01 00:00:00-06:00 2021-01-01 06:00:00+00:00
# 1 2021-01-01 00:05:00-06:00 2021-01-01 06:05:00+00:00
# 2 2021-01-01 00:10:00-06:00 2021-01-01 06:10:00+00:00
# 3 2021-01-01 00:15:00-06:00 2021-01-01 06:15:00+00:00
# 4 2021-01-01 00:20:00-06:00 2021-01-01 06:20:00+00:00
#
#          interval_end_local          interval_end_utc   load
# 0 2021-01-01 00:05:00-06:00 2021-01-01 06:05:00+00:00  43714
# 1 2021-01-01 00:10:00-06:00 2021-01-01 06:10:00+00:00  43681
# 2 2021-01-01 00:15:00-06:00 2021-01-01 06:15:00+00:00  43647
# 3 2021-01-01 00:20:00-06:00 2021-01-01 06:20:00+00:00  43614
# 4 2021-01-01 00:25:00-06:00 2021-01-01 06:25:00+00:00  43581

# %%
# Save to csv in clean_data folder
load_actuals_df.to_csv("../clean_data/ercot_load_actuals_2021_2024.csv", index=False)
