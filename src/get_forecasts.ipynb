# %%
import os
from dotenv import load_dotenv
from gridstatus import Ercot, Markets
from gridstatusio import GridStatusClient
from datetime import datetime, timedelta, date, time
from time import sleep
import pandas as pd
from pathlib import Path

# Load .env
load_dotenv()

API_KEY = os.getenv("GRIDSTATUS_API_KEY")
if API_KEY is None:
    raise RuntimeError("GRIDSTATUS_API_KEY not found in environment variables.")

client = GridStatusClient(api_key=API_KEY)
grid = Ercot()
QUERY_LIMIT = 100

start_date = date(2025, 1, 1)
end_date = date(2025, 9, 1)  # inclusive
out_dir = Path("../clean_data/forecasts").resolve()
out_dir.mkdir(parents=True, exist_ok=True)

all_dfs = []
for d in (start_date + timedelta(n) for n in range((end_date - start_date).days + 1)):
    s = d.strftime("%Y-%m-%d")
    e = (d + timedelta(days=1)).strftime("%Y-%m-%d")
    publish_str = "latest"  # use latest publish snapshot
    print(f"Requesting start={s} end={e} publish_time={publish_str}")
    try:
        df = client.get_dataset(dataset="ercot_load_forecast_dam", start=s, end=e, publish_time=publish_str, timezone="market")
    except Exception as err:
        print(f"Error fetching {s} with publish_time={publish_str}: {err}")
        df = None
    if df is None or len(df) == 0:
        print(f"No rows for {s} (publish {publish_str})")
        sleep(2)
        continue
    df = df.copy()
    df['forecast_date'] = s
    df['publish_time_used'] = publish_str
    all_dfs.append(df)
    # pause between API calls to avoid rate limits
    sleep(2)

if all_dfs:
    combined = pd.concat(all_dfs, ignore_index=True)
    combined_fname = out_dir / "ercot_load_forecast_2025-01-01_to_2025-09_01_combined_latest.csv"
    combined.to_csv(combined_fname, index=False)
    print("Saved combined CSV to:", combined_fname)
    print(combined.head())
else:
    print("No data found for the requested range.")
# Out:
# 2025-11-24 22:54:27 - INFO - Fetching Page 1...
# 2025-11-24 22:54:27 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:27 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2025-01-02 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:27 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:27 - INFO - Params: {'start_time': Timestamp('2025-01-01 00:00:00'), 'end_time': Timestamp('2025-01-02 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:27 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:54:27 - INFO - Total number of rows: 24
# 2025-11-24 22:54:27 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:54:27 - INFO - Total number of rows: 24
# Requesting start=2025-01-01 end=2025-01-02 publish_time=latest
# 2025-11-24 22:54:29 - INFO - Fetching Page 1...
# 2025-11-24 22:54:29 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:29 - INFO - Params: {'start_time': Timestamp('2025-01-02 00:00:00'), 'end_time': Timestamp('2025-01-03 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:29 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:29 - INFO - Params: {'start_time': Timestamp('2025-01-02 00:00:00'), 'end_time': Timestamp('2025-01-03 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:29 - INFO - Done in 0.12 seconds.
# 2025-11-24 22:54:29 - INFO - Total number of rows: 24
# 2025-11-24 22:54:29 - INFO - Done in 0.12 seconds.
# 2025-11-24 22:54:29 - INFO - Total number of rows: 24
# Requesting start=2025-01-02 end=2025-01-03 publish_time=latest
# 2025-11-24 22:54:32 - INFO - Fetching Page 1...
# 2025-11-24 22:54:32 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:32 - INFO - Params: {'start_time': Timestamp('2025-01-03 00:00:00'), 'end_time': Timestamp('2025-01-04 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:32 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:32 - INFO - Params: {'start_time': Timestamp('2025-01-03 00:00:00'), 'end_time': Timestamp('2025-01-04 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:32 - INFO - Done in 0.18 seconds.
# 2025-11-24 22:54:32 - INFO - Total number of rows: 24
# 2025-11-24 22:54:32 - INFO - Done in 0.18 seconds.
# 2025-11-24 22:54:32 - INFO - Total number of rows: 24
# Requesting start=2025-01-03 end=2025-01-04 publish_time=latest
# 2025-11-24 22:54:34 - INFO - Fetching Page 1...
# 2025-11-24 22:54:34 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:34 - INFO - Params: {'start_time': Timestamp('2025-01-04 00:00:00'), 'end_time': Timestamp('2025-01-05 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:34 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:34 - INFO - Params: {'start_time': Timestamp('2025-01-04 00:00:00'), 'end_time': Timestamp('2025-01-05 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:34 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:54:34 - INFO - Total number of rows: 24
# 2025-11-24 22:54:34 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:54:34 - INFO - Total number of rows: 24
# Requesting start=2025-01-04 end=2025-01-05 publish_time=latest
# 2025-11-24 22:54:36 - INFO - Fetching Page 1...
# 2025-11-24 22:54:36 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:36 - INFO - Params: {'start_time': Timestamp('2025-01-05 00:00:00'), 'end_time': Timestamp('2025-01-06 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:36 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:36 - INFO - Params: {'start_time': Timestamp('2025-01-05 00:00:00'), 'end_time': Timestamp('2025-01-06 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:36 - INFO - Done in 0.16 seconds.
# 2025-11-24 22:54:36 - INFO - Total number of rows: 24
# 2025-11-24 22:54:36 - INFO - Done in 0.16 seconds.
# 2025-11-24 22:54:36 - INFO - Total number of rows: 24
# Requesting start=2025-01-05 end=2025-01-06 publish_time=latest
# 2025-11-24 22:54:38 - INFO - Fetching Page 1...
# 2025-11-24 22:54:38 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:38 - INFO - Params: {'start_time': Timestamp('2025-01-06 00:00:00'), 'end_time': Timestamp('2025-01-07 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:38 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:38 - INFO - Params: {'start_time': Timestamp('2025-01-06 00:00:00'), 'end_time': Timestamp('2025-01-07 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:38 - INFO - Done in 0.13 seconds.
# 2025-11-24 22:54:38 - INFO - Total number of rows: 24
# 2025-11-24 22:54:38 - INFO - Done in 0.13 seconds.
# 2025-11-24 22:54:38 - INFO - Total number of rows: 24
# Requesting start=2025-01-06 end=2025-01-07 publish_time=latest
# 2025-11-24 22:54:40 - INFO - Fetching Page 1...
# 2025-11-24 22:54:40 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:40 - INFO - Params: {'start_time': Timestamp('2025-01-07 00:00:00'), 'end_time': Timestamp('2025-01-08 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:40 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:40 - INFO - Params: {'start_time': Timestamp('2025-01-07 00:00:00'), 'end_time': Timestamp('2025-01-08 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:40 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:54:40 - INFO - Total number of rows: 24
# 2025-11-24 22:54:40 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:54:40 - INFO - Total number of rows: 24
# Requesting start=2025-01-07 end=2025-01-08 publish_time=latest
# 2025-11-24 22:54:42 - INFO - Fetching Page 1...
# 2025-11-24 22:54:42 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:42 - INFO - Params: {'start_time': Timestamp('2025-01-08 00:00:00'), 'end_time': Timestamp('2025-01-09 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:42 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:42 - INFO - Params: {'start_time': Timestamp('2025-01-08 00:00:00'), 'end_time': Timestamp('2025-01-09 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Requesting start=2025-01-08 end=2025-01-09 publish_time=latest
# 2025-11-24 22:54:43 - INFO - Done in 0.23 seconds.
# 2025-11-24 22:54:43 - INFO - Total number of rows: 24
# 2025-11-24 22:54:43 - INFO - Total number of rows: 24
# 2025-11-24 22:54:45 - INFO - Fetching Page 1...
# 2025-11-24 22:54:45 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:45 - INFO - Params: {'start_time': Timestamp('2025-01-09 00:00:00'), 'end_time': Timestamp('2025-01-10 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:45 - INFO - Fetching Page 1...
# 2025-11-24 22:54:45 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:45 - INFO - Params: {'start_time': Timestamp('2025-01-09 00:00:00'), 'end_time': Timestamp('2025-01-10 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:45 - INFO - Done in 0.18 seconds.
# 2025-11-24 22:54:45 - INFO - Total number of rows: 24
# 2025-11-24 22:54:45 - INFO - Done in 0.18 seconds.
# 2025-11-24 22:54:45 - INFO - Total number of rows: 24
# Requesting start=2025-01-09 end=2025-01-10 publish_time=latest
# 2025-11-24 22:54:47 - INFO - Fetching Page 1...
# 2025-11-24 22:54:47 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:47 - INFO - Params: {'start_time': Timestamp('2025-01-10 00:00:00'), 'end_time': Timestamp('2025-01-11 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:47 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:47 - INFO - Params: {'start_time': Timestamp('2025-01-10 00:00:00'), 'end_time': Timestamp('2025-01-11 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:47 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:54:47 - INFO - Total number of rows: 24
# 2025-11-24 22:54:47 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:54:47 - INFO - Total number of rows: 24
# Requesting start=2025-01-10 end=2025-01-11 publish_time=latest
# 2025-11-24 22:54:49 - INFO - Fetching Page 1...
# 2025-11-24 22:54:49 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:49 - INFO - Params: {'start_time': Timestamp('2025-01-11 00:00:00'), 'end_time': Timestamp('2025-01-12 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:49 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:49 - INFO - Params: {'start_time': Timestamp('2025-01-11 00:00:00'), 'end_time': Timestamp('2025-01-12 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:49 - INFO - Done in 0.19 seconds.
# 2025-11-24 22:54:49 - INFO - Total number of rows: 24
# 2025-11-24 22:54:49 - INFO - Done in 0.19 seconds.
# 2025-11-24 22:54:49 - INFO - Total number of rows: 24
# Requesting start=2025-01-11 end=2025-01-12 publish_time=latest
# 2025-11-24 22:54:51 - INFO - Fetching Page 1...
# 2025-11-24 22:54:51 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:51 - INFO - Params: {'start_time': Timestamp('2025-01-12 00:00:00'), 'end_time': Timestamp('2025-01-13 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:51 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:51 - INFO - Params: {'start_time': Timestamp('2025-01-12 00:00:00'), 'end_time': Timestamp('2025-01-13 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:51 - INFO - Done in 0.2 seconds.
# 2025-11-24 22:54:51 - INFO - Total number of rows: 24
# 2025-11-24 22:54:51 - INFO - Done in 0.2 seconds.
# 2025-11-24 22:54:51 - INFO - Total number of rows: 24
# Requesting start=2025-01-12 end=2025-01-13 publish_time=latest
# 2025-11-24 22:54:53 - INFO - Fetching Page 1...
# 2025-11-24 22:54:53 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:53 - INFO - Params: {'start_time': Timestamp('2025-01-13 00:00:00'), 'end_time': Timestamp('2025-01-14 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:53 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:53 - INFO - Params: {'start_time': Timestamp('2025-01-13 00:00:00'), 'end_time': Timestamp('2025-01-14 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:54 - INFO - Done in 0.18 seconds.
# 2025-11-24 22:54:54 - INFO - Total number of rows: 24
# 2025-11-24 22:54:54 - INFO - Done in 0.18 seconds.
# 2025-11-24 22:54:54 - INFO - Total number of rows: 24
# Requesting start=2025-01-13 end=2025-01-14 publish_time=latest
# 2025-11-24 22:54:56 - INFO - Fetching Page 1...
# 2025-11-24 22:54:56 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:56 - INFO - Params: {'start_time': Timestamp('2025-01-14 00:00:00'), 'end_time': Timestamp('2025-01-15 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:56 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:56 - INFO - Params: {'start_time': Timestamp('2025-01-14 00:00:00'), 'end_time': Timestamp('2025-01-15 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Requesting start=2025-01-14 end=2025-01-15 publish_time=latest
# 2025-11-24 22:54:56 - INFO - Done in 0.25 seconds.
# 2025-11-24 22:54:56 - INFO - Total number of rows: 24
# 2025-11-24 22:54:56 - INFO - Total number of rows: 24
# 2025-11-24 22:54:58 - INFO - Fetching Page 1...
# 2025-11-24 22:54:58 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:58 - INFO - Params: {'start_time': Timestamp('2025-01-15 00:00:00'), 'end_time': Timestamp('2025-01-16 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:58 - INFO - Fetching Page 1...
# 2025-11-24 22:54:58 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:54:58 - INFO - Params: {'start_time': Timestamp('2025-01-15 00:00:00'), 'end_time': Timestamp('2025-01-16 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:54:58 - INFO - Done in 0.13 seconds.
# 2025-11-24 22:54:58 - INFO - Total number of rows: 24
# 2025-11-24 22:54:58 - INFO - Done in 0.13 seconds.
# 2025-11-24 22:54:58 - INFO - Total number of rows: 24
# Requesting start=2025-01-15 end=2025-01-16 publish_time=latest
# 2025-11-24 22:55:00 - INFO - Fetching Page 1...
# 2025-11-24 22:55:00 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:00 - INFO - Params: {'start_time': Timestamp('2025-01-16 00:00:00'), 'end_time': Timestamp('2025-01-17 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:00 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:00 - INFO - Params: {'start_time': Timestamp('2025-01-16 00:00:00'), 'end_time': Timestamp('2025-01-17 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Requesting start=2025-01-16 end=2025-01-17 publish_time=latest
# 2025-11-24 22:55:01 - INFO - Done in 0.99 seconds.
# 2025-11-24 22:55:01 - INFO - Total number of rows: 24
# 2025-11-24 22:55:01 - INFO - Total number of rows: 24
# 2025-11-24 22:55:03 - INFO - Fetching Page 1...
# 2025-11-24 22:55:03 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:03 - INFO - Params: {'start_time': Timestamp('2025-01-17 00:00:00'), 'end_time': Timestamp('2025-01-18 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:03 - INFO - Fetching Page 1...
# 2025-11-24 22:55:03 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:03 - INFO - Params: {'start_time': Timestamp('2025-01-17 00:00:00'), 'end_time': Timestamp('2025-01-18 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Requesting start=2025-01-17 end=2025-01-18 publish_time=latest
# 2025-11-24 22:55:03 - INFO - Done in 0.2 seconds.
# 2025-11-24 22:55:03 - INFO - Total number of rows: 24
# 2025-11-24 22:55:03 - INFO - Total number of rows: 24
# 2025-11-24 22:55:05 - INFO - Fetching Page 1...
# 2025-11-24 22:55:05 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:05 - INFO - Params: {'start_time': Timestamp('2025-01-18 00:00:00'), 'end_time': Timestamp('2025-01-19 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:05 - INFO - Fetching Page 1...
# 2025-11-24 22:55:05 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:05 - INFO - Params: {'start_time': Timestamp('2025-01-18 00:00:00'), 'end_time': Timestamp('2025-01-19 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:05 - INFO - Done in 0.19 seconds.
# 2025-11-24 22:55:05 - INFO - Total number of rows: 24
# 2025-11-24 22:55:05 - INFO - Done in 0.19 seconds.
# 2025-11-24 22:55:05 - INFO - Total number of rows: 24
# Requesting start=2025-01-18 end=2025-01-19 publish_time=latest
# 2025-11-24 22:55:07 - INFO - Fetching Page 1...
# 2025-11-24 22:55:07 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:07 - INFO - Params: {'start_time': Timestamp('2025-01-19 00:00:00'), 'end_time': Timestamp('2025-01-20 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:07 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:07 - INFO - Params: {'start_time': Timestamp('2025-01-19 00:00:00'), 'end_time': Timestamp('2025-01-20 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:08 - INFO - Done in 0.12 seconds.
# 2025-11-24 22:55:08 - INFO - Total number of rows: 24
# 2025-11-24 22:55:08 - INFO - Done in 0.12 seconds.
# 2025-11-24 22:55:08 - INFO - Total number of rows: 24
# Requesting start=2025-01-19 end=2025-01-20 publish_time=latest
# 2025-11-24 22:55:10 - INFO - Fetching Page 1...
# 2025-11-24 22:55:10 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:10 - INFO - Params: {'start_time': Timestamp('2025-01-20 00:00:00'), 'end_time': Timestamp('2025-01-21 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:10 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:10 - INFO - Params: {'start_time': Timestamp('2025-01-20 00:00:00'), 'end_time': Timestamp('2025-01-21 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Requesting start=2025-01-20 end=2025-01-21 publish_time=latest
# 2025-11-24 22:55:10 - INFO - Done in 0.21 seconds.
# 2025-11-24 22:55:10 - INFO - Total number of rows: 24
# 2025-11-24 22:55:10 - INFO - Total number of rows: 24
# 2025-11-24 22:55:12 - INFO - Fetching Page 1...
# 2025-11-24 22:55:12 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:12 - INFO - Params: {'start_time': Timestamp('2025-01-21 00:00:00'), 'end_time': Timestamp('2025-01-22 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:12 - INFO - Fetching Page 1...
# 2025-11-24 22:55:12 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:12 - INFO - Params: {'start_time': Timestamp('2025-01-21 00:00:00'), 'end_time': Timestamp('2025-01-22 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:12 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:12 - INFO - Total number of rows: 24
# 2025-11-24 22:55:12 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:12 - INFO - Total number of rows: 24
# Requesting start=2025-01-21 end=2025-01-22 publish_time=latest
# 2025-11-24 22:55:14 - INFO - Fetching Page 1...
# 2025-11-24 22:55:14 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:14 - INFO - Params: {'start_time': Timestamp('2025-01-22 00:00:00'), 'end_time': Timestamp('2025-01-23 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:14 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:14 - INFO - Params: {'start_time': Timestamp('2025-01-22 00:00:00'), 'end_time': Timestamp('2025-01-23 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:14 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:14 - INFO - Total number of rows: 24
# 2025-11-24 22:55:14 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:14 - INFO - Total number of rows: 24
# Requesting start=2025-01-22 end=2025-01-23 publish_time=latest
# 2025-11-24 22:55:16 - INFO - Fetching Page 1...
# 2025-11-24 22:55:16 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:16 - INFO - Params: {'start_time': Timestamp('2025-01-23 00:00:00'), 'end_time': Timestamp('2025-01-24 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:16 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:16 - INFO - Params: {'start_time': Timestamp('2025-01-23 00:00:00'), 'end_time': Timestamp('2025-01-24 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:16 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:55:16 - INFO - Total number of rows: 24
# 2025-11-24 22:55:16 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:55:16 - INFO - Total number of rows: 24
# Requesting start=2025-01-23 end=2025-01-24 publish_time=latest
# 2025-11-24 22:55:18 - INFO - Fetching Page 1...
# 2025-11-24 22:55:18 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:18 - INFO - Params: {'start_time': Timestamp('2025-01-24 00:00:00'), 'end_time': Timestamp('2025-01-25 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:18 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:18 - INFO - Params: {'start_time': Timestamp('2025-01-24 00:00:00'), 'end_time': Timestamp('2025-01-25 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:18 - INFO - Done in 0.17 seconds.
# 2025-11-24 22:55:18 - INFO - Total number of rows: 24
# 2025-11-24 22:55:18 - INFO - Done in 0.17 seconds.
# 2025-11-24 22:55:18 - INFO - Total number of rows: 24
# Requesting start=2025-01-24 end=2025-01-25 publish_time=latest
# 2025-11-24 22:55:20 - INFO - Fetching Page 1...
# 2025-11-24 22:55:20 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:20 - INFO - Params: {'start_time': Timestamp('2025-01-25 00:00:00'), 'end_time': Timestamp('2025-01-26 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:20 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:20 - INFO - Params: {'start_time': Timestamp('2025-01-25 00:00:00'), 'end_time': Timestamp('2025-01-26 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# Requesting start=2025-01-25 end=2025-01-26 publish_time=latest
# 2025-11-24 22:55:21 - INFO - Done in 0.27 seconds.
# 2025-11-24 22:55:21 - INFO - Total number of rows: 24
# 2025-11-24 22:55:21 - INFO - Total number of rows: 24
# 2025-11-24 22:55:23 - INFO - Fetching Page 1...
# 2025-11-24 22:55:23 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:23 - INFO - Params: {'start_time': Timestamp('2025-01-26 00:00:00'), 'end_time': Timestamp('2025-01-27 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:23 - INFO - Fetching Page 1...
# 2025-11-24 22:55:23 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:23 - INFO - Params: {'start_time': Timestamp('2025-01-26 00:00:00'), 'end_time': Timestamp('2025-01-27 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:23 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:23 - INFO - Total number of rows: 24
# 2025-11-24 22:55:23 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:23 - INFO - Total number of rows: 24
# Requesting start=2025-01-26 end=2025-01-27 publish_time=latest
# 2025-11-24 22:55:25 - INFO - Fetching Page 1...
# 2025-11-24 22:55:25 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:25 - INFO - Params: {'start_time': Timestamp('2025-01-27 00:00:00'), 'end_time': Timestamp('2025-01-28 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:25 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:25 - INFO - Params: {'start_time': Timestamp('2025-01-27 00:00:00'), 'end_time': Timestamp('2025-01-28 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:25 - INFO - Done in 0.17 seconds.
# 2025-11-24 22:55:25 - INFO - Total number of rows: 24
# 2025-11-24 22:55:25 - INFO - Done in 0.17 seconds.
# 2025-11-24 22:55:25 - INFO - Total number of rows: 24
# Requesting start=2025-01-27 end=2025-01-28 publish_time=latest
# 2025-11-24 22:55:27 - INFO - Fetching Page 1...
# 2025-11-24 22:55:27 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:27 - INFO - Params: {'start_time': Timestamp('2025-01-28 00:00:00'), 'end_time': Timestamp('2025-01-29 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:27 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:27 - INFO - Params: {'start_time': Timestamp('2025-01-28 00:00:00'), 'end_time': Timestamp('2025-01-29 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:27 - INFO - Done in 0.17 seconds.
# 2025-11-24 22:55:27 - INFO - Total number of rows: 24
# 2025-11-24 22:55:27 - INFO - Done in 0.17 seconds.
# 2025-11-24 22:55:27 - INFO - Total number of rows: 24
# Requesting start=2025-01-28 end=2025-01-29 publish_time=latest
# 2025-11-24 22:55:29 - INFO - Fetching Page 1...
# 2025-11-24 22:55:29 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:29 - INFO - Params: {'start_time': Timestamp('2025-01-29 00:00:00'), 'end_time': Timestamp('2025-01-30 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:29 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:29 - INFO - Params: {'start_time': Timestamp('2025-01-29 00:00:00'), 'end_time': Timestamp('2025-01-30 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:29 - INFO - Done in 0.16 seconds.
# 2025-11-24 22:55:29 - INFO - Total number of rows: 24
# 2025-11-24 22:55:29 - INFO - Done in 0.16 seconds.
# 2025-11-24 22:55:29 - INFO - Total number of rows: 24
# Requesting start=2025-01-29 end=2025-01-30 publish_time=latest
# 2025-11-24 22:55:31 - INFO - Fetching Page 1...
# 2025-11-24 22:55:31 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:31 - INFO - Params: {'start_time': Timestamp('2025-01-30 00:00:00'), 'end_time': Timestamp('2025-01-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:31 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:31 - INFO - Params: {'start_time': Timestamp('2025-01-30 00:00:00'), 'end_time': Timestamp('2025-01-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:32 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:55:32 - INFO - Total number of rows: 24
# 2025-11-24 22:55:32 - INFO - Done in 0.15 seconds.
# 2025-11-24 22:55:32 - INFO - Total number of rows: 24
# Requesting start=2025-01-30 end=2025-01-31 publish_time=latest
# 2025-11-24 22:55:34 - INFO - Fetching Page 1...
# 2025-11-24 22:55:34 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:34 - INFO - Params: {'start_time': Timestamp('2025-01-31 00:00:00'), 'end_time': Timestamp('2025-02-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:34 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:34 - INFO - Params: {'start_time': Timestamp('2025-01-31 00:00:00'), 'end_time': Timestamp('2025-02-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:34 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:34 - INFO - Total number of rows: 24
# 2025-11-24 22:55:34 - INFO - Done in 0.14 seconds.
# 2025-11-24 22:55:34 - INFO - Total number of rows: 24
# Requesting start=2025-01-31 end=2025-02-01 publish_time=latest
# 2025-11-24 22:55:36 - INFO - Fetching Page 1...
# 2025-11-24 22:55:36 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 22:55:36 - INFO - Params: {'start_time': Timestamp('2025-02-01 00:00:00'), 'end_time': Timestamp('2025-02-02 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 22:55:36 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# ...
# 2025-11-24 23:03:07 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:07 - INFO - Total number of rows: 24
# Requesting start=2025-08-24 end=2025-08-25 publish_time=latest
# 2025-11-24 23:03:09 - INFO - Fetching Page 1...
# 2025-11-24 23:03:09 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:09 - INFO - Params: {'start_time': Timestamp('2025-08-25 00:00:00'), 'end_time': Timestamp('2025-08-26 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:09 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:09 - INFO - Params: {'start_time': Timestamp('2025-08-25 00:00:00'), 'end_time': Timestamp('2025-08-26 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:09 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:09 - INFO - Total number of rows: 24
# 2025-11-24 23:03:09 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:09 - INFO - Total number of rows: 24
# Requesting start=2025-08-25 end=2025-08-26 publish_time=latest
# 2025-11-24 23:03:11 - INFO - Fetching Page 1...
# 2025-11-24 23:03:11 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:11 - INFO - Params: {'start_time': Timestamp('2025-08-26 00:00:00'), 'end_time': Timestamp('2025-08-27 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:11 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:11 - INFO - Params: {'start_time': Timestamp('2025-08-26 00:00:00'), 'end_time': Timestamp('2025-08-27 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:12 - INFO - Done in 0.15 seconds.
# 2025-11-24 23:03:12 - INFO - Total number of rows: 24
# 2025-11-24 23:03:12 - INFO - Done in 0.15 seconds.
# 2025-11-24 23:03:12 - INFO - Total number of rows: 24
# Requesting start=2025-08-26 end=2025-08-27 publish_time=latest
# 2025-11-24 23:03:14 - INFO - Fetching Page 1...
# 2025-11-24 23:03:14 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:14 - INFO - Params: {'start_time': Timestamp('2025-08-27 00:00:00'), 'end_time': Timestamp('2025-08-28 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:14 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:14 - INFO - Params: {'start_time': Timestamp('2025-08-27 00:00:00'), 'end_time': Timestamp('2025-08-28 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:14 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:14 - INFO - Total number of rows: 24
# 2025-11-24 23:03:14 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:14 - INFO - Total number of rows: 24
# Requesting start=2025-08-27 end=2025-08-28 publish_time=latest
# 2025-11-24 23:03:16 - INFO - Fetching Page 1...
# 2025-11-24 23:03:16 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:16 - INFO - Params: {'start_time': Timestamp('2025-08-28 00:00:00'), 'end_time': Timestamp('2025-08-29 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:16 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:16 - INFO - Params: {'start_time': Timestamp('2025-08-28 00:00:00'), 'end_time': Timestamp('2025-08-29 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:16 - INFO - Done in 0.12 seconds.
# 2025-11-24 23:03:16 - INFO - Total number of rows: 24
# 2025-11-24 23:03:16 - INFO - Done in 0.12 seconds.
# 2025-11-24 23:03:16 - INFO - Total number of rows: 24
# Requesting start=2025-08-28 end=2025-08-29 publish_time=latest
# 2025-11-24 23:03:18 - INFO - Fetching Page 1...
# 2025-11-24 23:03:18 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:18 - INFO - Params: {'start_time': Timestamp('2025-08-29 00:00:00'), 'end_time': Timestamp('2025-08-30 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:18 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:18 - INFO - Params: {'start_time': Timestamp('2025-08-29 00:00:00'), 'end_time': Timestamp('2025-08-30 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:18 - INFO - Done in 0.19 seconds.
# 2025-11-24 23:03:18 - INFO - Total number of rows: 24
# 2025-11-24 23:03:18 - INFO - Done in 0.19 seconds.
# 2025-11-24 23:03:18 - INFO - Total number of rows: 24
# Requesting start=2025-08-29 end=2025-08-30 publish_time=latest
# 2025-11-24 23:03:20 - INFO - Fetching Page 1...
# 2025-11-24 23:03:20 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:20 - INFO - Params: {'start_time': Timestamp('2025-08-30 00:00:00'), 'end_time': Timestamp('2025-08-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:20 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:20 - INFO - Params: {'start_time': Timestamp('2025-08-30 00:00:00'), 'end_time': Timestamp('2025-08-31 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:20 - INFO - Done in 0.19 seconds.
# 2025-11-24 23:03:20 - INFO - Done in 0.19 seconds.
# 2025-11-24 23:03:20 - INFO - Total number of rows: 24
# 2025-11-24 23:03:20 - INFO - Total number of rows: 24
# Requesting start=2025-08-30 end=2025-08-31 publish_time=latest
# 2025-11-24 23:03:22 - INFO - Fetching Page 1...
# 2025-11-24 23:03:22 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:22 - INFO - Params: {'start_time': Timestamp('2025-08-31 00:00:00'), 'end_time': Timestamp('2025-09-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:22 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:22 - INFO - Params: {'start_time': Timestamp('2025-08-31 00:00:00'), 'end_time': Timestamp('2025-09-01 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:22 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:22 - INFO - Total number of rows: 24
# 2025-11-24 23:03:22 - INFO - Done in 0.14 seconds.
# 2025-11-24 23:03:22 - INFO - Total number of rows: 24
# Requesting start=2025-08-31 end=2025-09-01 publish_time=latest
# 2025-11-24 23:03:24 - INFO - Fetching Page 1...
# 2025-11-24 23:03:24 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:24 - INFO - Params: {'start_time': Timestamp('2025-09-01 00:00:00'), 'end_time': Timestamp('2025-09-02 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:24 - INFO - GET https://api.gridstatus.io/v1/datasets/ercot_load_forecast_dam/query
# 2025-11-24 23:03:24 - INFO - Params: {'start_time': Timestamp('2025-09-01 00:00:00'), 'end_time': Timestamp('2025-09-02 00:00:00'), 'publish_time_start': None, 'publish_time_end': None, 'limit': None, 'page': 1, 'page_size': None, 'resample_frequency': None, 'resample_by': None, 'resample_function': None, 'publish_time': 'latest', 'timezone': 'market', 'cursor': '', 'filter_column': None, 'filter_value': None, 'filter_operator': '=', 'return_format': 'json', 'json_schema': 'array-of-arrays'}
# 2025-11-24 23:03:25 - INFO - Done in 0.13 seconds.
# 2025-11-24 23:03:25 - INFO - Total number of rows: 24
# 2025-11-24 23:03:25 - INFO - Done in 0.13 seconds.
# 2025-11-24 23:03:25 - INFO - Total number of rows: 24
# Requesting start=2025-09-01 end=2025-09-02 publish_time=latest
# Saved combined CSV to: /Users/eric/ERCOT_Peaker_Project/clean_data/forecasts/ercot_load_forecast_2025-01-01_to_2025-09_01_combined_latest.csv
#        interval_start_local        interval_start_utc  \
# 0 2025-01-01 00:00:00-06:00 2025-01-01 06:00:00+00:00
# 1 2025-01-01 01:00:00-06:00 2025-01-01 07:00:00+00:00
# 2 2025-01-01 02:00:00-06:00 2025-01-01 08:00:00+00:00
# 3 2025-01-01 03:00:00-06:00 2025-01-01 09:00:00+00:00
# 4 2025-01-01 04:00:00-06:00 2025-01-01 10:00:00+00:00
#
#          interval_end_local          interval_end_utc  \
# 0 2025-01-01 01:00:00-06:00 2025-01-01 07:00:00+00:00
# 1 2025-01-01 02:00:00-06:00 2025-01-01 08:00:00+00:00
# 2 2025-01-01 03:00:00-06:00 2025-01-01 09:00:00+00:00
# 3 2025-01-01 04:00:00-06:00 2025-01-01 10:00:00+00:00
# 4 2025-01-01 05:00:00-06:00 2025-01-01 11:00:00+00:00
#
#          publish_time_local          publish_time_utc         north  \
# 0 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15241.269815
# 1 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15086.945770
# 2 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15049.549788
# 3 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15072.950313
# 4 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15414.521239
#
#           south         west       houston  system_total forecast_date  \
# 0  10764.112549  8686.966742  10447.770644  45140.119751    2025-01-01
# 1  10641.859974  8727.281459  10371.972978  44828.060181    2025-01-01
# 2  10540.620259  8756.140120  10196.219130  44542.529297    2025-01-01
# 3  10397.694547  8760.957437  10116.567624  44348.169922    2025-01-01
# 4  10539.003254  8800.289386  10136.126551  44889.940430    2025-01-01
#
#   publish_time_used
# 0            latest
# 1            latest
# 2            latest
# 3            latest
# 4            latest
# Saved combined CSV to: /Users/eric/ERCOT_Peaker_Project/clean_data/forecasts/ercot_load_forecast_2025-01-01_to_2025-09_01_combined_latest.csv
#        interval_start_local        interval_start_utc  \
# 0 2025-01-01 00:00:00-06:00 2025-01-01 06:00:00+00:00
# 1 2025-01-01 01:00:00-06:00 2025-01-01 07:00:00+00:00
# 2 2025-01-01 02:00:00-06:00 2025-01-01 08:00:00+00:00
# 3 2025-01-01 03:00:00-06:00 2025-01-01 09:00:00+00:00
# 4 2025-01-01 04:00:00-06:00 2025-01-01 10:00:00+00:00
#
#          interval_end_local          interval_end_utc  \
# 0 2025-01-01 01:00:00-06:00 2025-01-01 07:00:00+00:00
# 1 2025-01-01 02:00:00-06:00 2025-01-01 08:00:00+00:00
# 2 2025-01-01 03:00:00-06:00 2025-01-01 09:00:00+00:00
# 3 2025-01-01 04:00:00-06:00 2025-01-01 10:00:00+00:00
# 4 2025-01-01 05:00:00-06:00 2025-01-01 11:00:00+00:00
#
#          publish_time_local          publish_time_utc         north  \
# 0 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15241.269815
# 1 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15086.945770
# 2 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15049.549788
# 3 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15072.950313
# 4 2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15414.521239
#
#           south         west       houston  system_total forecast_date  \
# 0  10764.112549  8686.966742  10447.770644  45140.119751    2025-01-01
# 1  10641.859974  8727.281459  10371.972978  44828.060181    2025-01-01
# 2  10540.620259  8756.140120  10196.219130  44542.529297    2025-01-01
# 3  10397.694547  8760.957437  10116.567624  44348.169922    2025-01-01
# 4  10539.003254  8800.289386  10136.126551  44889.940430    2025-01-01
#
#   publish_time_used
# 0            latest
# 1            latest
# 2            latest
# 3            latest
# 4            latest

# %%
#df.drop(columns=["south", "north", "west", "houston"], inplace=True)
combined
# Out:
#           interval_start_local        interval_start_utc  \
# 0    2025-01-01 00:00:00-06:00 2025-01-01 06:00:00+00:00
# 1    2025-01-01 01:00:00-06:00 2025-01-01 07:00:00+00:00
# 2    2025-01-01 02:00:00-06:00 2025-01-01 08:00:00+00:00
# 3    2025-01-01 03:00:00-06:00 2025-01-01 09:00:00+00:00
# 4    2025-01-01 04:00:00-06:00 2025-01-01 10:00:00+00:00
# ...                        ...                       ...
# 5850 2025-09-01 19:00:00-05:00 2025-09-02 00:00:00+00:00
# 5851 2025-09-01 20:00:00-05:00 2025-09-02 01:00:00+00:00
# 5852 2025-09-01 21:00:00-05:00 2025-09-02 02:00:00+00:00
# 5853 2025-09-01 22:00:00-05:00 2025-09-02 03:00:00+00:00
# 5854 2025-09-01 23:00:00-05:00 2025-09-02 04:00:00+00:00
#
#             interval_end_local          interval_end_utc  \
# 0    2025-01-01 01:00:00-06:00 2025-01-01 07:00:00+00:00
# 1    2025-01-01 02:00:00-06:00 2025-01-01 08:00:00+00:00
# 2    2025-01-01 03:00:00-06:00 2025-01-01 09:00:00+00:00
# 3    2025-01-01 04:00:00-06:00 2025-01-01 10:00:00+00:00
# 4    2025-01-01 05:00:00-06:00 2025-01-01 11:00:00+00:00
# ...                        ...                       ...
# 5850 2025-09-01 20:00:00-05:00 2025-09-02 01:00:00+00:00
# 5851 2025-09-01 21:00:00-05:00 2025-09-02 02:00:00+00:00
# 5852 2025-09-01 22:00:00-05:00 2025-09-02 03:00:00+00:00
# 5853 2025-09-01 23:00:00-05:00 2025-09-02 04:00:00+00:00
# 5854 2025-09-02 00:00:00-05:00 2025-09-02 05:00:00+00:00
#
#             publish_time_local          publish_time_utc         north  \
# 0    2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15241.269815
# 1    2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15086.945770
# 2    2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15049.549788
# 3    2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15072.950313
# 4    2024-12-31 14:30:00-06:00 2024-12-31 20:30:00+00:00  15414.521239
# ...                        ...                       ...           ...
# 5850 2025-09-01 14:30:00-05:00 2025-09-01 19:30:00+00:00  22241.071967
# 5851 2025-09-01 14:30:00-05:00 2025-09-01 19:30:00+00:00  21813.496493
# 5852 2025-09-01 14:30:00-05:00 2025-09-01 19:30:00+00:00  21002.078085
# 5853 2025-09-01 14:30:00-05:00 2025-09-01 19:30:00+00:00  19619.205515
# 5854 2025-09-01 14:30:00-05:00 2025-09-01 19:30:00+00:00  18174.345390
#
#              south          west       houston  system_total forecast_date  \
# 0     10764.112549   8686.966742  10447.770644  45140.119751    2025-01-01
# 1     10641.859974   8727.281459  10371.972978  44828.060181    2025-01-01
# 2     10540.620259   8756.140120  10196.219130  44542.529297    2025-01-01
# 3     10397.694547   8760.957437  10116.567624  44348.169922    2025-01-01
# 4     10539.003254   8800.289386  10136.126551  44889.940430    2025-01-01
# ...            ...           ...           ...           ...           ...
# 5850  18870.465318  10040.374075  16038.479997  67190.391357    2025-09-01
# 5851  18542.753168   9856.300697  16009.210384  66221.760742    2025-09-01
# 5852  17876.684619   9738.057478  15582.149300  64198.969482    2025-09-01
# 5853  16869.694650   9667.684929  14852.403553  61008.988647    2025-09-01
# 5854  15739.559837   9541.473080  14217.951649  57673.329956    2025-09-01
#
#      publish_time_used
# 0               latest
# 1               latest
# 2               latest
# 3               latest
# 4               latest
# ...                ...
# 5850            latest
# 5851            latest
# 5852            latest
# 5853            latest
# 5854            latest
#
# [5855 rows x 13 columns]
